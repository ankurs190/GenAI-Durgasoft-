# %% [markdown]
# <a href="https://colab.research.google.com/github/ankurs190/GenAI-Durgasoft-/blob/main/Generative_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **GenAI Intro**

# %% [markdown]
# #### **Session 93 (6th Aug) - Generative AI Intro**

# %% [markdown]
#       - What is Generative AI
#       - Types of Generative AI Model
#         - Language Model
#         - Small Language Model
#         - Medium Language Model
#         - Large Language Model
#       - Transformers
#         - Transformers - Self Attention
#            BERT
#       GPT
#       ChatGPT
#       Prompt Engineering
#       Hugging Face
#       LangChain
#       Liama
#       LangChain
#       Models
#       Prompt Templates
#       Output Parsers
#       Chains
#       Agents
#       RAG Agents

# %% [markdown]
# - What is Generative AI : It is a branch of artificial intelligence that focuses on creating new content — such as text, images, audio, code, or even 3D models — instead of just analyzing existing data.
# - It’s called generative because it generates new outputs, often resembling things a human might create.
# - Generative AI regenerates new content by learning patterns from existing data.
# - Generative AI is very sensitive toward the input provided in the form of prompt
#
# - Types of Generative Models-
#       • GANs ==> Generative Adversarial Networks
#       • VAE ==> Variational Auto Encoders
#       • Diffusion
#
# | Model Type    | Core Mechanism                 | Output Quality     | Training Stability | Speed | Popular Uses                        |
# | ------------- | ------------------------------ | ------------------ | ------------------ | ----- | ----------------------------------- |
# | **GANs**      | Generator vs Discriminator     | Very sharp images  | Medium–Low         | Fast  | Faces, art, style transfer          |
# | **VAE**       | Encode → latent space → decode | Decent but softer  | High               | Fast  | Data compression, anomaly detection |
# | **Diffusion** | Noise → gradual denoising      | Extremely detailed | High               | Slow  | Art, photorealism, image editing    |

# %% [markdown]
#     Language Model : A Language model is a type of Artificial Intelligence model which is specially designed to understand and generate human language.
#     These Language Models are used for
#            Sentiment Analysis
#            Chat Bosts
#            Text Summarization
#            Text Translations
#
# | Model Size | Typical Parameter Range               | Memory & Compute Needs                          | Speed                                   | Context Window         | Strengths                                                                              | Weaknesses                                                                | Best Use Cases                                                                                     | Example Models                                  |
# | ---------- | ------------------------------------- | ----------------------------------------------- | --------------------------------------- | ---------------------- | -------------------------------------------------------------------------------------- | ------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------- | ----------------------------------------------- |
# | **Small**  | **< 1B parameters**                   | Low — can run on CPU or small GPU (4–8 GB VRAM) | **Fast**                                | Short (1k–4k tokens)   | Low cost; easy to deploy; good for edge devices; low latency                           | Limited reasoning; weak long-context understanding; less factual accuracy | Edge AI apps, basic chatbots, keyword extraction, lightweight summarization                        | DistilBERT, TinyLlama, GPT-2 small              |
# | **Medium** | **1B – 20B parameters**               | Moderate — needs mid/high GPU (16–48 GB VRAM)   | Medium                                  | Medium (4k–32k tokens) | Better reasoning and accuracy; handles more complex prompts; balanced cost-performance | Slower than small; still weaker than large in deep reasoning & creativity | Customer support bots, advanced summarization, structured data extraction, fine-tuned domain tasks | GPT-J (6B), LLaMA-2 13B, Mistral 7B             |
# | **Large**  | **> 20B parameters** (often 70B–500B) | High — needs multi-GPU clusters or cloud TPU    | Slower (can be optimized with batching) | Long (32k–1M+ tokens)  | Best reasoning, creativity, factual accuracy; understands nuance; handles long context | High cost; high latency; large infrastructure needs                       | Research, coding assistants, multi-turn reasoning, complex planning                                | GPT-4, Claude 3 Opus, LLaMA-3 70B, Gemini Ultra |

# %% [markdown]
# | Company             | Model (Latest)  | Context Window   | Multi-Modal                   | Open Source | Speed\* | Safety & Reliability | Notable Specialties                              |
# | ------------------- | --------------- | ---------------- | ----------------------------- | ----------- | ------- | -------------------- | ------------------------------------------------ |
# | **OpenAI**          | GPT-5           | 256K (est.)      | ✅ (text, image, audio, video) | ❌           | ⚡⚡⚡     | ⭐⭐⭐⭐                 | Best general reasoning, coding, creative writing |
# | **OpenAI**          | GPT-4o          | 128K             | ✅                             | ❌           | ⚡⚡⚡⚡    | ⭐⭐⭐⭐                 | Real-time multi-modal chat, translation          |
# | **Google DeepMind** | Gemini 2.5 Pro  | 1M               | ✅                             | ❌           | ⚡⚡      | ⭐⭐⭐⭐                 | Math, logic, search integration                  |
# | **Anthropic**       | Claude 3.5 Opus | 200K+            | ❌                             | ❌           | ⚡⚡      | ⭐⭐⭐⭐⭐                | Safe outputs, long-form summarization            |
# | **Meta AI**         | LLaMA 3.2       | 8K–128K (varies) | ❌                             | ✅           | ⚡⚡⚡     | ⭐⭐⭐                  | On-prem & fine-tuning flexibility                |
# | **Mistral AI**      | Mixtral 8×22B   | 64K              | ❌                             | ✅           | ⚡⚡⚡⚡    | ⭐⭐⭐                  | Mixture-of-Experts efficiency                    |
# | **Cohere**          | Command R+      | 128K             | ❌                             | ❌           | ⚡⚡⚡     | ⭐⭐⭐⭐                 | Retrieval-augmented generation (RAG)             |
# | **Inflection AI**   | Pi 2024         | 32K              | ❌                             | ❌           | ⚡⚡⚡     | ⭐⭐⭐⭐                 | Empathetic conversation                          |
# | **xAI**             | Grok 2          | 32K              | ❌                             | ❌           | ⚡⚡⚡⚡    | ⭐⭐⭐                  | Real-time X (Twitter) integration                |

# %% [markdown]
# LLM Training
#
#
# | **Stage**                                                | **Description**                                                              | **Key Techniques / Tools**                                                             | **Output**                       |
# | -------------------------------------------------------- | ---------------------------------------------------------------------------- | -------------------------------------------------------------------------------------- | -------------------------------- |
# | **1. Data Collection**                                   | Gather large-scale text & code from multiple sources.                        | Web scraping, Common Crawl, Wikipedia, GitHub, books, curated datasets.                | Raw, diverse corpus.             |
# | **2. Data Cleaning & Filtering**                         | Remove duplicates, low-quality, or harmful text. Balance topics & languages. | Regex filters, deduplication algorithms, profanity filtering.                          | High-quality dataset.            |
# | **3. Tokenization**                                      | Convert text into tokens (subwords/words).                                   | Byte Pair Encoding (BPE), SentencePiece.                                               | Numerical token IDs.             |
# | **4. Pretraining**                                       | Train model to predict next token using massive data.                        | Transformer architecture, cross-entropy loss, distributed training (GPU/TPU clusters). | Base LLM with general knowledge. |
# | **5. Fine-Tuning**                                       | Train further on domain/task-specific data.                                  | Supervised fine-tuning, LoRA, PEFT.                                                    | Specialized LLM.                 |
# | **6. RLHF (Reinforcement Learning from Human Feedback)** | Align model to human preferences & safety.                                   | Reward model, PPO (Proximal Policy Optimization).                                      | Instruction-following, safe LLM. |
# | **7. Evaluation & Testing**                              | Assess accuracy, reasoning, safety, bias.                                    | Benchmarks (MMLU, TruthfulQA, HumanEval).                                              | Quality-verified LLM.            |
# | **8. Deployment**                                        | Optimize and integrate into applications.                                    | Quantization, inference optimization, APIs.                                            | Production-ready LLM service.    |

# %% [markdown]
# #### **Session 94 (8th Aug) - Generative AI Intro Cont**

# %% [markdown]
#     Large Language Models (LLMs) :
#     - LLMs are a type of artificial intelligence model which is trained with large volume data. These models can perform multi task by generating new content.
#     - LLMs are build on deep learning and reinforcement learning techniques. These models can understand and recognize the patterns from the input data and can generate human like content based on prompt.
#     - Core Components of LLMs :
#       - Deep Learning & Reinforcement Learning :LLM's are subset of deep learning and reinforcement learning which are a branch of Machine Learning that uses Artificial Neural Network.
#       - Transformers : Transformers are heart of LLMs. These can be considered as core fundamental Architecture of LLMs.
#       - Massive Data : LLM's are trained with humongous data . LLM's are designed to perform a specific task for which they are trained with massive datasets.
#       - Tokenization : Prior to model processing the test, it has to broken down in to smaller units which are referred tokens.
#       - Embeddings : Converting tokens (smaller text units) into numerical representation in the form dense vector is called Embedding. These embedding helps to capture the semantic meaning of token allowing the model to understand relationship between words in a sequence.
#       -  Attention Mechanism / Self - Attention Mechanism : This is a very import component of transformer architecture which enables model to concentrate on most relevant parts of the input sequence when generating output
#       - Parameter Tuning : LLM's has a very large volume of parameters. These parameters are adjusted during the training process to optimize the model performance.
#       - Parameter : These are very important components in the model whose values can changed to enhance performance of the model.

# %% [markdown]
# #### **Session 95 (11th Aug) -LLM & Transformers**

# %% [markdown]
# - Types of LLMs Based on Architecture
#   - Transformer based LLM
#   - Mixture of Experts (MoE) LLM
#   - Retrieval Augmented LLM (RAG)
#   - Hybrid Architecture
#   - Multimodal LLM
#
#
# - **Transformer based LLM**- We can create LLM using encoder only (BERT), decoder only (GPT), and encoder+decoder (BART, T5).
#       - Encoder-Only Transformers: for prediction purpose
#         - An encoder based LLM refers to a type of LLM that is build using encoder part of transformer
#         - Best for understanding text (classification, sentiment analysis, named entity recognition, etc.).
#         - Key Feature: Reads the entire input sequence at once (bidirectional attention).
#
# | Model          | Organization    | Notes                                                                      |
# | -------------- | --------------- | -------------------------------------------------------------------------- |
# | **BERT**       | Google          | Bi-directional encoder for deep language understanding.                    |
# | **RoBERTa**    | Facebook (Meta) | Robustly optimized version of BERT.                                        |
# | **DistilBERT** | Hugging Face    | Smaller, faster BERT with \~40% fewer parameters.                          |
# | **ALBERT**     | Google/TTI      | Lighter BERT with parameter sharing.                                       |
# | **DeBERTa**    | Microsoft       | Improved attention and position encoding.                                  |
# | **ELECTRA**    | Google          | Trains faster by replacing masked LM with a discriminator-generator setup. |
#
#
#     2. Decoder-Only Transformers: for generative AI purpose
#     - A decoder based LLM is a type of LLM model that uses only decoder portion of original transfomer architecture
#     - Purpose: Best for text generation (next token prediction, story writing, code generation).
#     - Key Feature: Processes input left-to-right (causal attention).
#
# | Model                          | Organization          | Notes                                  |
# | ------------------------------ | --------------------- | -------------------------------------- |
# | **GPT (1, 2, 3, 4, 4o, 5)**    | OpenAI                | Autoregressive generative model.       |
# | **LLaMA (1, 2, 3)**            | Meta                  | Open-source GPT-style model.           |
# | **Mistral / Mixtral**          | Mistral AI            | Efficient small decoder-only models.   |
# | **Falcon**                     | TII                   | Optimized for large-scale generation.  |
# | **Gemini Nano (decoder part)** | Google DeepMind       | Mobile-friendly generation models.     |
# | **CodeGen / StarCoder**        | Hugging Face & others | Code generation-specific transformers. |
#
#
#     3. Encoder–Decoder (Seq2Seq) Transformers
#     - These LLM uses both encoder and decoder portion of transformer
#     - Purpose: Best for tasks that transform one sequence into another (translation, summarization, Q&A).
#     - Key Feature: Encoder reads input, decoder generates output conditioned on encoded representation.
#
# | Model                                      | Organization | Notes                                                       |
# | ------------------------------------------ | ------------ | ----------------------------------------------------------- |
# | **BART**                                   | Meta         | Combines bidirectional encoder with autoregressive decoder. |
# | **T5 (Text-to-Text Transfer Transformer)** | Google       | Converts every task into a text-to-text problem.            |
# | **MarianMT**                               | Hugging Face | Optimized for translation tasks.                            |
# | **Pegasus**                                | Google       | Summarization-focused model with gap-sentence pretraining.  |
# | **FLAN-T5**                                | Google       | Instruction-tuned version of T5.                            |
# | **mBART**                                  | Meta         | Multilingual version of BART for translation.               |

# %% [markdown]
# **Mixture of Experts (MoE) LLM**
#
#   - These type of LLMs are designed to perform tasks more efficiently
#   - These are combination of small subset language models which are referred as "Experts" (ex: finance+ Image+ Manufacturing + Healthcare)
#   - Experts are basically specialized neural networks sub-models which are expertized with specific tasks
#
#
# | **Aspect**             | **Explanation**                                                                                                   |
# | ---------------------- | ----------------------------------------------------------------------------------------------------------------- |
# | **Purpose**            | Designed to perform tasks more efficiently by activating only the most relevant parts of the model.               |
# | **Structure**          | Composed of multiple smaller sub-models called **"Experts"**.                                                     |
# | **Experts**            | Specialized neural network components trained to handle specific types of patterns or tasks.                      |
# | **Routing**            | A **Router (Gating Network)** decides which experts to activate for each input or token.                          |
# | **Activation Pattern** | Only a small subset of experts (Top-K) are activated per input, making computation **sparse** and cost-effective. |
# | **Benefit**            | Can scale parameters into trillions while keeping computational cost manageable.                                  |
# | **Example Models**     | Switch Transformer (Google), GLaM (Google), Mixtral (Mistral AI), DeepSpeed-MoE (Microsoft).                      |

# %% [markdown]
# **Retrieval Augmented LLM (RAG)**
# - RAG = Retrieval + Augmented + Generation
# - It’s a hybrid approach where the LLM doesn’t just rely on what it learned during training — it retrieves relevant external knowledge before generating an answer.
#
#
#       1. Core Idea
#       - Traditional LLMs are static — they can only use knowledge from their training data (which gets outdated).
#       - RAG models pull in fresh, domain-specific, or private data from an external knowledge base (vector database, search index, documents) in real-time.
#       - Then the retrieved context is fed into the LLM’s prompt before generation.
#
#       2. How It Works
#       - User Query → Comes in as input.
#       - Retrieval Step → Query is converted into an embedding vector and searched in a vector database (e.g., Pinecone, Weaviate, Milvus, FAISS).
#       - Context Augmentation → The retrieved documents/snippets are appended to the prompt as extra context.
#       - Generation Step → LLM uses the combined input (query + retrieved context) to generate an accurate, up-to-date answer.
#
#       3. Advantages
#       - Freshness — Can use the most recent data without retraining.
#       - Domain Adaptability — Can work with private/company datasets.
#       - Cost Efficiency — No need to retrain the LLM for every data update.
#       - Explainability — Can cite sources used for the answer.
#
#       4. Disadvantages
#       - Retrieval Quality Dependency — If retrieval fetches irrelevant data, output quality drops.
#       - Latency — Retrieval step adds extra processing time.
#       - Context Limit — The LLM has a maximum token limit, so you can’t overload it with too much retrieved text.
#
#       5 Example
#
# | Model / System                  | Retrieval Source      | Notes                        |
# | ------------------------------- | --------------------- | ---------------------------- |
# | **OpenAI GPT with Bing Search** | Web search API        | Adds real-time internet data |
# | **LangChain + Llama-Index**     | Custom knowledge base | Open-source RAG pipelines    |
# | **ChatGPT Retrieval Plugin**    | User’s own documents  | Allows private doc search    |
# | **Perplexity AI**               | Web search + LLM      | Always cites sources         |
#
#
#       [ User Query ]
#             ↓
#       [ Retriever: Search Knowledge Base ]
#             ↓
#       [ Retrieved Context + Query ]
#             ↓
#       [ LLM Generates Answer ]

# %% [markdown]
#     RAG Process
#     <!-- ![Screenshot 2025-08-13 151405.png](data:image/png;base64,...) -->

# %% [markdown]
# **Hybrid Architectire LLM**
# - Hybrid LLMs combine different architectural types (Encoder-only, Decoder-only, Encoder+Decoder, MoE) or training approaches (RAG, fine-tuning, adapters) in a single system to maximize performance, adaptability, and efficiency.
#
# **MultiModal LLM**
# - A MultiModal Large Language Model is an LLM that can process and generate content across multiple data modalities — such as text, images, audio, video, and even structured data — instead of just text.
# - They use transformer archtitecture
# - common Modalities
#
#
# | Modality        | Description                               | Example Task                                   |
# | --------------- | ----------------------------------------- | ---------------------------------------------- |
# | **Text**        | Natural language sentences.               | Summarization, Q\&A, chatbots.                 |
# | **Image**       | Visual understanding and generation.      | Captioning, image editing, object recognition. |
# | **Audio**       | Speech recognition, sound classification. | Transcription, voice commands.                 |
# | **Video**       | Frame-based + temporal understanding.     | Video summarization, activity detection.       |
# | **Code**        | Programming language processing.          | Code generation, debugging.                    |
# | **Sensor Data** | IoT or structured sensor streams.         | Predictive maintenance, anomaly detection.     |

# %% [markdown]
#  **Major Drawbacks of LLM**
#
#     - Data Privacy Risk : If LLM is fine tuned with private data then a strict rules has to be followed in order to avoid data leakage.
#     - Resource Intensity : LLM resources intensity refers to how large computational powered demanded for LLM
#     - Large Computational Power :
#       - Hardware : Training a Large Language Model like Gemini 2.5, GPT 4.0, Llama 3 which consumes thousands of GPU /TPU which may take months to complete training.
#       - Energy : LLM training requires large energy (Electricity) Training a GPT - 4 model consumes approx hundreds of megawatt of energy.
#       - Memory : LLM requires large memory resources --> RAM 500 - 1000 VRAM in single system.
#       - Time : To train LLM with Large volume of data it requires months of time.
#
#   * **Knowledge Limits** – Outdated data, hallucinations, no real understanding.
#   * **Bias & Ethics** – Inherits bias, can produce harmful or unbalanced content.
#   * **High Cost** – Expensive to train, run, and maintain; high energy use.
#   * **Context Limits** – Fixed token window, forgets older context.
#   * **Reasoning Gaps** – Weak in complex logic or niche domains.
#   * **Security Risks** – Vulnerable to prompt injection, data leakage, misuse.
#   * **Lack of Explainability** – Black box behavior, hard to debug.
#   * **Overreliance Risk** – Can cause skill loss and spread misinformation.

# %% [markdown]
# ### **Transformers** (** Interview)

# %% [markdown]
# #### **Session 96 (12th Aug) - Transformers**

# %% [markdown]
# **Evolution of Architectures**
#
# - Traditional ML
#   - Couldn’t handle large & multi-dimensional data.
#   - Mostly limited to structured data and single-task learning.
# - ANN (Artificial Neural Networks)
#   - Could process grayscale images.
#   - Struggled with very high-dimensional inputs like color images.
# - CNN (Convolutional Neural Networks)
#   - Specially designed for images (RGB, color).
#   - Great for spatial data but weak for sequential/textual data.
# - RNN (Recurrent Neural Networks)
#   - Designed for sequence/text data.
#   - Problem: struggled with long-term dependencies due to vanishing gradients.
# - LSTM (Long Short-Term Memory)
#   - Improved RNNs by handling long dependencies.
#   - Still complex and slow for very large datasets/tasks.
#   - Drawback of LSTM- Computational Costly, Complex Architecture, Risk of Over Fitting, Training Time
# Interpretability
# - Seq2Seq (Encoder-Decoder with LSTMs/GRUs)- https://arxiv.org/pdf/1409.3215
#   - Used in machine translation and summarization.
#   - Problem: Sequential processing = slow + limited context.
# - Attention Mechanism
#   - Solved bottleneck of seq2seq by letting model “attend” to relevant parts of the input sequence dynamically.
#   - Allowed parallelization instead of step-by-step processing.
#   - Major breakthrough toward scalability.
# - Self Attention
# - Transformers (Attention-Only Models)
#   - Fully based on self-attention.
#   - Can process massive parallel data, capture long dependencies efficiently
#   - Backbone of BERT, GPT, T5, LLaMA, etc.
#   - Improved contextual meaning ( better than semantic meaning)
#   -  Autoscalability
#   - Transfomrer released by Google in 2017 through a paper called  Transformers (2017, "Attention is All You Need")- https://arxiv.org/pdf/1706.03762
#
#   ML → ANN → CNN → RNN → LSTM → Seq2Seq → Attention → Transformers → LLMs.

# %% [markdown]
#     - A Transformer is a deep learning architecture designed to process sequential data (like text, speech, or DNA) using the self-attention mechanism, which enables the model to understand contextual meaning and relationships between tokens, regardless of their position in the sequence.
#     - Transformers can handle long dependencies and parallel processing
#     - Self attention helps us to understand contextual realtionship between different long standing dependencies in a input sequence
#
#     Key Points (for quick recall):
#     📌 Parallel processing of sequences (faster than RNN/LSTM).
#     📌 Self-Attention → focuses on relevant words in context
#     📌 Positional Encoding → keeps track of word order.
#     📌 Scalable → foundation of LLMs (BERT, GPT, T5). encoder and decoder are autoscalable. from 6 to many depending on requirement

# %% [markdown]
# https://pub.towardsai.net/transformer-architecture-part-1-d157b54315e6
#
# https://www.analyticsvidhya.com/blog/2024/04/understanding-transformers-a-deep-dive-into-nlps-core-technology/

# %% [markdown]
# #### **Session 97 (14th Aug) - Transformers Encoder**
# https://pub.towardsai.net/transformer-architecture-part-1-d157b54315e6

# %% [markdown]
# **Encoder of Transformer**
# - it accepts the input sequence, understands it and convert it into set of meaningful vectors which in-turn forwared to decoder for further process
# - Core components of encoder
#   - Input -> Tokenization + Text Vectorization (Embedding) + Positional Encoding = Input embeddings
#   - Mult-head Self Attention
#   - Residual Connection (Normalization) and Addition - Add & Norm
#   - Feed Forward Neural Network
#
# **Encoder Architecture**
# - **Input** – sequential textual data which is going to be processed
#   - Example: "Transformers are powerful."
#   - Raw text cannot be fed directly → needs preprocessing.
# - **Input Embeddings Stage**: This converts raw text into numerical form for the model.
#   - **Tokenization**: Breaks the sentence into tokens (words, subwords, or characters). Example (WordPiece/BPE): "Transformers" → "Trans", "former", "s"
#   - **Vocabulary Mapping**: extract unique words & providing number represenation to them. Example: "Trans" → 1053, "former" → 8942
#   - **Embedding Lookup**: Each ID is mapped to a dense vector based on similarity and semantic meaning (no zeros, sparse vector lot of zeros) (say, 768 dimensions. Example: 1053 → [0.25, -0.67, …, 0.89]
#
# - **Positional Encoding**: It is a technique in transformer model to remember the position of each token in a input sequence.
#   - As transformers process input senquence parallely which in-turn results in loosing the actual positions of token which is retained by positional encoder
#   -  of two types
#     - Absolute- Token is at position n
#     - Relative- This token is k steps away from another token
#
# Since Transformers have no recurrence or convolution, they need explicit position info. Adds a sinusoidal or learned vector to embeddings so the model knows word order.

# %% [markdown]
# #### **Session 98 (16th Aug) - Transformers Encoder**

# %%
 # example : BERT

# %% [markdown]
# | **Step**                                   | **What Happens**                                                     | **Example with “How are you”**                                                                              |
# | ------------------------------------------ | -------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------- |
# | **1. Input Text**                          | Raw sequential text enters the model.                                | `"How are you"`                                                                                             |
# | **2. Tokenization**                        | Sentence is split into tokens (sub-words/words).                     | `["How", "are", "you"]`                                                                                     |
# | **3. Vocabulary Mapping**                  | Tokens mapped to integer IDs from vocabulary.                        | `How → 101`, `are → 202`, `you → 303`                                                                       |
# | **4. Word Embeddings**                     | Each token ID converted into dense vector (learned during training). | `How → [0.2, 0.4, 0.6]`<br>`are → [0.5, 0.1, 0.3]`<br>`you → [0.9, 0.7, 0.2]`                               |
# | **5. Positional Encoding**                 | Position info added to embeddings (so model knows order).            | `How (pos0) → [0.21, 0.39, 0.64]`<br>`are (pos1) → [0.55, 0.15, 0.32]`<br>`you (pos2) → [0.93, 0.72, 0.25]` |
# | **6. Input to Encoder Block**              | Embeddings + positions passed to encoder layer.                      | Matrix of size (3 tokens × embedding\_dim)                                                                  |
# | **7. Self-Attention (Scaled Dot Product)** | Each token attends to others → learns context.                       | `"you"` attends strongly to `"are"`, weakly to `"How"`.                                                     |
# | **8. Add & Norm**                          | Residual connection + layer normalization.                           | Ensures stability & better gradient flow.                                                                   |
# | **9. Feed Forward Network**                | Each token passes through small neural network (non-linear).         | Transforms features for better representation.                                                              |
# | **10. Add & Norm (again)**                 | Residual + normalization after FFN.                                  | Final refined embeddings.                                                                                   |
# | **11. Encoder Output**                     | Context-aware representation of each token.                          | `"How"` = greeting, `"are"` = verb, `"you"` = subject → all linked semantically.                            |

# %% [markdown]
# https://medium.com/towards-artificial-intelligence/transformer-architecture-part-2-db1c0df20a0d

# %% [markdown]
# Self-Attention is a mechanism in Transformers that lets each word in a sentence interact with every other word to capture relationships and context.
# It answers:
# 👉 “When processing this word, which other words in the sentence should I pay attention to?”
#
# self attention derived from attention, attention derived from encoder-decoder
#
#     📖 Mini Example: "How are you"
#     Imagine embeddings are very small (just 2D for simplicity).
#     Input: ["How", "are", "you"]
#     Step:
#     "How" creates Q, K, V.
#     Q("How") is compared with K("How"), K("are"), K("you").
#     Suppose similarity scores = [0.7, 0.2, 0.1].
#     After softmax = [0.6, 0.25, 0.15].
#     Final representation of "How" =
#     0.6×V("How") + 0.25×V("are") + 0.15×V("you").
#     So, “How” no longer just means “How” → it now understands its context (“How are you”).

# %% [markdown]
# #### **Session 99 (18th Aug) - Encoder Decoder Architecture**

# %% [markdown]
# - **Drawback of LSTM**- Computational Costly, Complex Architecture, Risk of Over Fitting, Training Time, Interpretability

# %% [markdown]
# **Seq2Seq-Encoder-Decoder-LSTM-Model** -https://www.researchgate.net/publication/344664783_A_Systematic_Review_on_Sequence_to_Sequence_Neural_Network_and_its_Models
# - The Encoder - Decoder Model is a type of Neural Network
# architecture used to convert an input sequence data into output
# sequence data.
# - Encoder ==> It accepts input sequence from the user to process it and
# compress the information into a context vector .
# - Context Vector: It holds processed compressed information generated form
# input sequence. It holds important information which decoder requires to
# generate output.
# - Decoder:  It accepts compressed information from context vector and
# generate output in step by step process. Based on context vector it generates the output one word at a time.

# %% [markdown]
# ![Screenshot 2025-08-21 124747.png](data:image/png;base64,...)

# %% [markdown]
# #### **Session 100 (19th Aug) - Attention Mechanism**

# %% [markdown]
# - Attention mechanism in transformers vs humans
# - Attention in Human visual processing system
#   - Brain puts more focus on word your are currently reading
#   - your brain doesn't care about most of the mechanism
#
#
# - In a vanilla RNN encoder–decoder, the last hidden state of the encoder (LSTM) was used to summarize the entire input sequence into a single vector.
# - Each word/ token is allocated to one LSTM cell
# - This worked fine for short sentences. But for long inputs, it became a bottleneck → the model forgot earlier information. 👉 That’s why attention was invented:
# - Instead of only using the last one, the decoder can attend to all encoder states, weighting them according to relevance at each decoding step.
# - Drawbacks of Encoder - Decoder Model-
#
#       ○ Very long Dependencies cannot be handled- In the basic RNN/LSTM encoder–decoder, the entire source sequence is compressed into one fixed-length vector (the final hidden state). This makes it difficult to capture information from long inputs, since earlier words fade due to vanishing gradients.
#       ○ Lack of Alignment- In tasks like translation, we expect the output words to align with specific input words. Vanilla encoder–decoder has no mechanism to align input and output tokens.This causes problems when translating languages with different word orders. (This issue is solved by attention, which learns soft alignments.)
#       ○ Loss Information- Because the model forces the encoder to squash everything into one context vector, some information is inevitably lost. Rich details about input tokens, relationships, and nuances are discarded.
#       ○ High Computational Cost
#       ○ Interpretability is difficult- In the vanilla version, we cannot see which parts of the input influenced the output. Everything is hidden inside one fixed-length state vector. With attention, we gain attention weights, which provide interpretable alignment.
#
#       👉 That’s why attention and later transformers became the dominant architecture — they fix alignment, long-dependency handling, and interpretability, while being more parallelizable.
#
# 🔹 Encoder–Decoder with Attention (simplified flow)
#
#     - Input: “The cat sat on the mat.”
#     - Encoder: Produces hidden states for each token (h₁, h₂, h₃, …, hₙ).
#     - Decoder (predicting word “chat” in French):
#     - Computes attention weights for all h₁…hₙ.
#     - Maybe gives high weight to “cat,” some weight to “The,” less to “mat.”
#     - Weighted sum of encoder states (context vector) + decoder state → prediction.
#     ✅ So, in plain encoder–decoder: “last one holds.”
#     ✅ In encoder–decoder with attention: “all of them hold, but differently weighted.”

# %% [markdown]
# ![Screenshot 2025-08-25 112059.png](data:image/png;base64,...)

# %% [markdown]
# 🔄 Encoder–Decoder Evolution
#
# | Aspect                         | **Vanilla Encoder–Decoder (RNN/LSTM)**                                      | **Encoder–Decoder + Attention**                                  | **Transformer**                                                    |
# | ------------------------------ | --------------------------------------------------------------------------- | ---------------------------------------------------------------- | ------------------------------------------------------------------ |
# | **Handling Long Dependencies** | ❌ Poor — all info squashed into last hidden state → long sentences get lost | ✅ Better — decoder can attend to all encoder states              | ✅ Excellent — self-attention captures global dependencies directly |
# | **Alignment (Input ↔ Output)** | ❌ None — no explicit link between input & output tokens                     | ✅ Yes — attention learns soft alignments                         | ✅ Strong — attention layers model dependencies across all tokens   |
# | **Information Loss**           | ❌ High — fixed-length context vector loses details                          | ✅ Reduced — attends to multiple encoder states instead of one    | ✅ Minimal — all tokens directly interact through attention         |
# | **Computational Cost**         | ❌ High for long sequences (sequential RNN steps, hard to parallelize)       | ❌ Still high (attention adds cost, but still sequential in RNNs) | ✅ Much lower — highly parallelizable on GPUs/TPUs                  |
# | **Interpretability**           | ❌ Opaque — can’t see which inputs influenced outputs                        | ✅ Partial — attention weights give interpretable alignments      | ✅ Stronger — attention maps show clear relationships               |
# | **Scalability**                | ❌ Limited — struggles with long documents                                   | ⚠️ Better but still limited by RNN sequential nature             | ✅ Scales to very long sequences with variants (e.g., Longformer)   |

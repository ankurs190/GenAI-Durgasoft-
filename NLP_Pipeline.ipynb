# %% [markdown]
# <a href="https://colab.research.google.com/github/ankurs190/GenAI-Durgasoft-/blob/main/NLP_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
df = pd.read_csv("/content/drive/MyDrive/DS Class Notes/DS_GenAI_8,30 PM_0325/June - 2025/NLP/27 - June - 2025/IMDB.csv")

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.sample(10000)
# Out:
#                                                   review sentiment
# 27914  The English Patient is one of those films that...  positive
# 8769   What the F*@# was this I just watched? Steven ...  negative
# 37535  I had such high hopes for Teletoon Retro to ai...  positive
# 24323  Note: I've tried not to give away any importan...  positive
# 5123   Easily one of the best shows ever made, & it j...  positive
# ...                                                  ...       ...
# 48903  An unfunny, unworthy picture which is an undes...  negative
# 27424  This film is something like a sequel of "White...  negative
# 18664  This picture seemed way to slanted, it's almos...  negative
# 33029  I've just been at the cinema in down town Prag...  negative
# 26971  Henry (Don Ameche) turns up at the entrance to...  negative
#
# [10000 rows x 2 columns]

# %%
df1 = df.sample(10000)

# %%
df1["sentiment"].value_counts()
# Out:
# sentiment
# positive    5027
# negative    4973
# Name: count, dtype: int64

# %%
df1
# Out:
#                                                   review sentiment
# 33838  Pretty lousy made-for-TV sequel to the Roman P...  negative
# 18446  A fine ironic visual gag takes place in front ...  positive
# 8824   This is the worst movie I have seen since "I K...  negative
# 4773   I went into this movie perhaps a bit jaded by ...  positive
# 43362  'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...                                                  ...       ...
# 24081  Very businesslike authority with little respon...  negative
# 38049  It's nice that these three young directors hav...  negative
# 35386  I rented this movie tonight because it looked ...  negative
# 8236   In all truth, this really isn't a "movie" so m...  positive
# 2134   Anthony Quinn is a master at capturing our hea...  positive
#
# [10000 rows x 2 columns]

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#       index                                             review sentiment
# 0     33838  Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1     18446  A fine ironic visual gag takes place in front ...  positive
# 2      8824  This is the worst movie I have seen since "I K...  negative
# 3      4773  I went into this movie perhaps a bit jaded by ...  positive
# 4     43362  'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...     ...                                                ...       ...
# 9995  24081  Very businesslike authority with little respon...  negative
# 9996  38049  It's nice that these three young directors hav...  negative
# 9997  35386  I rented this movie tonight because it looked ...  negative
# 9998   8236  In all truth, this really isn't a "movie" so m...  positive
# 9999   2134  Anthony Quinn is a master at capturing our hea...  positive
#
# [10000 rows x 3 columns]

# %%
df1.drop("index", axis = 1)
# Out:
#                                                  review sentiment
# 0     Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1     A fine ironic visual gag takes place in front ...  positive
# 2     This is the worst movie I have seen since "I K...  negative
# 3     I went into this movie perhaps a bit jaded by ...  positive
# 4     'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...                                                 ...       ...
# 9995  Very businesslike authority with little respon...  negative
# 9996  It's nice that these three young directors hav...  negative
# 9997  I rented this movie tonight because it looked ...  negative
# 9998  In all truth, this really isn't a "movie" so m...  positive
# 9999  Anthony Quinn is a master at capturing our hea...  positive
#
# [10000 rows x 2 columns]

# %%
df1.drop("index", axis = 1, inplace = True)

# %%
df1
# Out:
#                                                  review sentiment
# 0     Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1     A fine ironic visual gag takes place in front ...  positive
# 2     This is the worst movie I have seen since "I K...  negative
# 3     I went into this movie perhaps a bit jaded by ...  positive
# 4     'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...                                                 ...       ...
# 9995  Very businesslike authority with little respon...  negative
# 9996  It's nice that these three young directors hav...  negative
# 9997  I rented this movie tonight because it looked ...  negative
# 9998  In all truth, this really isn't a "movie" so m...  positive
# 9999  Anthony Quinn is a master at capturing our hea...  positive
#
# [10000 rows x 2 columns]

# %%
df1["review"]
# Out:
# 0       Pretty lousy made-for-TV sequel to the Roman P...
# 1       A fine ironic visual gag takes place in front ...
# 2       This is the worst movie I have seen since "I K...
# 3       I went into this movie perhaps a bit jaded by ...
# 4       'Captain Corelli's Mandolin' is a fantastic fi...
#                               ...
# 9995    Very businesslike authority with little respon...
# 9996    It's nice that these three young directors hav...
# 9997    I rented this movie tonight because it looked ...
# 9998    In all truth, this really isn't a "movie" so m...
# 9999    Anthony Quinn is a master at capturing our hea...
# Name: review, Length: 10000, dtype: object

# %%
df1["review"].map(lambda x : x.upper())
# Out:
# 0       PRETTY LOUSY MADE-FOR-TV SEQUEL TO THE ROMAN P...
# 1       A FINE IRONIC VISUAL GAG TAKES PLACE IN FRONT ...
# 2       THIS IS THE WORST MOVIE I HAVE SEEN SINCE "I K...
# 3       I WENT INTO THIS MOVIE PERHAPS A BIT JADED BY ...
# 4       'CAPTAIN CORELLI'S MANDOLIN' IS A FANTASTIC FI...
#                               ...
# 9995    VERY BUSINESSLIKE AUTHORITY WITH LITTLE RESPON...
# 9996    IT'S NICE THAT THESE THREE YOUNG DIRECTORS HAV...
# 9997    I RENTED THIS MOVIE TONIGHT BECAUSE IT LOOKED ...
# 9998    IN ALL TRUTH, THIS REALLY ISN'T A "MOVIE" SO M...
# 9999    ANTHONY QUINN IS A MASTER AT CAPTURING OUR HEA...
# Name: review, Length: 10000, dtype: object

# %%
df1["review"].map(lambda x : x.lower())
# Out:
# 0       pretty lousy made-for-tv sequel to the roman p...
# 1       a fine ironic visual gag takes place in front ...
# 2       this is the worst movie i have seen since "i k...
# 3       i went into this movie perhaps a bit jaded by ...
# 4       'captain corelli's mandolin' is a fantastic fi...
#                               ...
# 9995    very businesslike authority with little respon...
# 9996    it's nice that these three young directors hav...
# 9997    i rented this movie tonight because it looked ...
# 9998    in all truth, this really isn't a "movie" so m...
# 9999    anthony quinn is a master at capturing our hea...
# Name: review, Length: 10000, dtype: object

# %%
df1["review"]
# Out:
# 0       Pretty lousy made-for-TV sequel to the Roman P...
# 1       A fine ironic visual gag takes place in front ...
# 2       This is the worst movie I have seen since "I K...
# 3       I went into this movie perhaps a bit jaded by ...
# 4       'Captain Corelli's Mandolin' is a fantastic fi...
#                               ...
# 9995    Very businesslike authority with little respon...
# 9996    It's nice that these three young directors hav...
# 9997    I rented this movie tonight because it looked ...
# 9998    In all truth, this really isn't a "movie" so m...
# 9999    Anthony Quinn is a master at capturing our hea...
# Name: review, Length: 10000, dtype: object

# %%
df1["Result"] = df1["review"].map(lambda x : x.lower())

# %%
df1
# Out:
#                                                  review sentiment  \
# 0     Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1     A fine ironic visual gag takes place in front ...  positive
# 2     This is the worst movie I have seen since "I K...  negative
# 3     I went into this movie perhaps a bit jaded by ...  positive
# 4     'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...                                                 ...       ...
# 9995  Very businesslike authority with little respon...  negative
# 9996  It's nice that these three young directors hav...  negative
# 9997  I rented this movie tonight because it looked ...  negative
# 9998  In all truth, this really isn't a "movie" so m...  positive
# 9999  Anthony Quinn is a master at capturing our hea...  positive
#
#                                                  Result
# 0     pretty lousy made-for-tv sequel to the roman p...
# 1     a fine ironic visual gag takes place in front ...
# ...

# %%
df1["Result"].map(lambda x :  re.findall("<.*?>", x))
# Out:
# 0                                                      []
# 1                                                      []
# 2        [<br />, <br />, <br />, <br />, <br />, <br />]
# 3                                                      []
# 4                                                      []
#                               ...
# 9995                     [<br />, <br />, <br />, <br />]
# 9996                     [<br />, <br />, <br />, <br />]
# 9997    [<br />, <br />, <br />, <br />, <br />, <br /...
# 9998                                                   []
# 9999                                                   []
# Name: Result, Length: 10000, dtype: object

# %%
df1["Result"].map(lambda x :  len(x))
# Out:
# 0       1099
# 1        271
# 2        696
# 3       1507
# 4        709
#         ...
# 9995    1375
# 9996    1144
# 9997     880
# 9998    1522
# 9999     727
# Name: Result, Length: 10000, dtype: int64

# %%
df1["Result"].map(lambda x :  re.sub("<.*?>","", x))
# Out:
# 0       pretty lousy made-for-tv sequel to the roman p...
# 1       a fine ironic visual gag takes place in front ...
# 2       this is the worst movie i have seen since "i k...
# 3       i went into this movie perhaps a bit jaded by ...
# 4       'captain corelli's mandolin' is a fantastic fi...
#                               ...
# 9995    very businesslike authority with little respon...
# 9996    it's nice that these three young directors hav...
# 9997    i rented this movie tonight because it looked ...
# 9998    in all truth, this really isn't a "movie" so m...
# 9999    anthony quinn is a master at capturing our hea...
# Name: Result, Length: 10000, dtype: object

# %%
df1["Result"] = df1["Result"].map(lambda x :  re.sub("<.*?>","", x))

# %%
df1["Result"].map(lambda x :  len(x))
# Out:
# 0       1099
# 1        271
# 2        660
# 3       1507
# 4        709
#         ...
# 9995    1351
# 9996    1120
# 9997     796
# 9998    1522
# 9999     727
# Name: Result, Length: 10000, dtype: int64

# %%
import string

# %%
from string import punctuation

# %%
punc = punctuation

# %%
df1
# Out:
#                                                  review sentiment  \
# 0     Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1     A fine ironic visual gag takes place in front ...  positive
# 2     This is the worst movie I have seen since "I K...  negative
# 3     I went into this movie perhaps a bit jaded by ...  positive
# 4     'Captain Corelli's Mandolin' is a fantastic fi...  positive
# ...                                                 ...       ...
# 9995  Very businesslike authority with little respon...  negative
# 9996  It's nice that these three young directors hav...  negative
# 9997  I rented this movie tonight because it looked ...  negative
# 9998  In all truth, this really isn't a "movie" so m...  positive
# 9999  Anthony Quinn is a master at capturing our hea...  positive
#
#                                                  Result
# 0     pretty lousy made-for-tv sequel to the roman p...
# 1     a fine ironic visual gag takes place in front ...
# ...

# %%
df1["Result"][0]
# Out:
# "pretty lousy made-for-tv sequel to the roman polanski classic. rosemary's son adrian has grown up and is embodied by creepy stephen mchattie. after eliminating rosemary (here played by patty duke) a coven of witches, again led by minnie & roman castevets, preps satan's son for world domination. it's not really scary and light years less macabre than its predecessor. instead, writer anthony wilson and director sam o'steen opt for a satan-worshiping thriller full of a lot of chanting, plenty of candles, and ruth gordon trying to act daffy and nasty at the same time. gordon's the sole holdover from the original. george maharis replaces john cassavetes as guy and a very hammy ray milland plays roman castevets, subbing for the late sidney blackmer. newcomer mchattie is the film's only real saving grace. he's very off-kilter and looks really sinister without even doing anything. the music by charles bernstein is suitably creepy, but so over-used, it's ends up being intrusive rather than e
# ...

# %%
"".join( [ c   for c in df1["Result"][0] if c not in punc] )
# Out:
# 'pretty lousy madefortv sequel to the roman polanski classic rosemarys son adrian has grown up and is embodied by creepy stephen mchattie after eliminating rosemary here played by patty duke a coven of witches again led by minnie  roman castevets preps satans son for world domination its not really scary and light years less macabre than its predecessor instead writer anthony wilson and director sam osteen opt for a satanworshiping thriller full of a lot of chanting plenty of candles and ruth gordon trying to act daffy and nasty at the same time gordons the sole holdover from the original george maharis replaces john cassavetes as guy and a very hammy ray milland plays roman castevets subbing for the late sidney blackmer newcomer mchattie is the films only real saving grace hes very offkilter and looks really sinister without even doing anything the music by charles bernstein is suitably creepy but so overused its ends up being intrusive rather than effective osteen who edited the ea
# ...

# %%
len(df1["Result"][0])
# Out:
# 1099

# %%
len("".join( [ c   for c in df1["Result"][0] if c not in punc] ))
# Out:
# 1061

# %% [markdown]
# ## **Punctuation Marks**

# %%
df1["Result"]
# Out:
# 0       pretty lousy made-for-tv sequel to the roman p...
# 1       a fine ironic visual gag takes place in front ...
# 2       this is the worst movie i have seen since "i k...
# 3       i went into this movie perhaps a bit jaded by ...
# 4       'captain corelli's mandolin' is a fantastic fi...
#                               ...
# 9995    very businesslike authority with little respon...
# 9996    it's nice that these three young directors hav...
# 9997    i rented this movie tonight because it looked ...
# 9998    in all truth, this really isn't a "movie" so m...
# 9999    anthony quinn is a master at capturing our hea...
# Name: Result, Length: 10000, dtype: object

# %%
df1["Result"].map(lambda x : [ c   for c in x  if c not in punc] )
# Out:
# 0       [p, r, e, t, t, y,  , l, o, u, s, y,  , m, a, ...
# 1       [a,  , f, i, n, e,  , i, r, o, n, i, c,  , v, ...
# 2       [t, h, i, s,  , i, s,  , t, h, e,  , w, o, r, ...
# 3       [i,  , w, e, n, t,  , i, n, t, o,  , t, h, i, ...
# 4       [c, a, p, t, a, i, n,  , c, o, r, e, l, l, i, ...
#                               ...
# 9995    [v, e, r, y,  , b, u, s, i, n, e, s, s, l, i, ...
# 9996    [i, t, s,  , n, i, c, e,  , t, h, a, t,  , t, ...
# 9997    [i,  , r, e, n, t, e, d,  , t, h, i, s,  , m, ...
# 9998    [i, n,  , a, l, l,  , t, r, u, t, h,  , t, h, ...
# 9999    [a, n, t, h, o, n, y,  , q, u, i, n, n,  , i, ...
# Name: Result, Length: 10000, dtype: object

# %%
df1["Result"].map(lambda x : "".join([ c   for c in x  if c not in punc]))
# Out:
# 0       pretty lousy madefortv sequel to the roman pol...
# 1       a fine ironic visual gag takes place in front ...
# 2       this is the worst movie i have seen since i kn...
# 3       i went into this movie perhaps a bit jaded by ...
# 4       captain corellis mandolin is a fantastic film ...
#                               ...
# 9995    very businesslike authority with little respon...
# 9996    its nice that these three young directors have...
# 9997    i rented this movie tonight because it looked ...
# 9998    in all truth this really isnt a movie so much ...
# 9999    anthony quinn is a master at capturing our hea...
# Name: Result, Length: 10000, dtype: object

# %%
df1["Result"] = df1["Result"].map(lambda x : "".join([ c   for c in x  if c not in punc]))

# %% [markdown]
# ## **Tokenization**

# %%
df1.head()
# Out:
#                                               review sentiment  \
# 0  Pretty lousy made-for-TV sequel to the Roman P...  negative
# 1  A fine ironic visual gag takes place in front ...  positive
# 2  This is the worst movie I have seen since "I K...  negative
# 3  I went into this movie perhaps a bit jaded by ...  positive
# 4  'Captain Corelli's Mandolin' is a fantastic fi...  positive
#
#                                               Result
# 0  pretty lousy madefortv sequel to the roman pol...
# 1  a fine ironic visual gag takes place in front ...
# 2  this is the worst movie i have seen since i kn...
# 3  i went into this movie perhaps a bit jaded by ...
# 4  captain corellis mandolin is a fantastic film ...

# %%
df1.drop("review", axis = 1)
# Out:
#      sentiment                                             Result
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
# [10000 rows x 2 columns]

# %%
df1.drop("review", axis = 1, inplace = True)

# %%
df1
# Out:
#      sentiment                                             Result
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
# [10000 rows x 2 columns]

# %%
df1.columns
# Out:
# Index(['sentiment', 'Result'], dtype='object')

# %%
df1.columns = ['sentiment', 'Review']

# %%
df1
# Out:
#      sentiment                                             Review
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
# [10000 rows x 2 columns]

# %%
df1["Review"]
# Out:
# 0       pretty lousy madefortv sequel to the roman pol...
# 1       a fine ironic visual gag takes place in front ...
# 2       this is the worst movie i have seen since i kn...
# 3       i went into this movie perhaps a bit jaded by ...
# 4       captain corellis mandolin is a fantastic film ...
#                               ...
# 9995    very businesslike authority with little respon...
# 9996    its nice that these three young directors have...
# 9997    i rented this movie tonight because it looked ...
# 9998    in all truth this really isnt a movie so much ...
# 9999    anthony quinn is a master at capturing our hea...
# Name: Review, Length: 10000, dtype: object

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
df1["Review"][0]
# Out:
# 'pretty lousy madefortv sequel to the roman polanski classic rosemarys son adrian has grown up and is embodied by creepy stephen mchattie after eliminating rosemary here played by patty duke a coven of witches again led by minnie  roman castevets preps satans son for world domination its not really scary and light years less macabre than its predecessor instead writer anthony wilson and director sam osteen opt for a satanworshiping thriller full of a lot of chanting plenty of candles and ruth gordon trying to act daffy and nasty at the same time gordons the sole holdover from the original george maharis replaces john cassavetes as guy and a very hammy ray milland plays roman castevets subbing for the late sidney blackmer newcomer mchattie is the films only real saving grace hes very offkilter and looks really sinister without even doing anything the music by charles bernstein is suitably creepy but so overused its ends up being intrusive rather than effective osteen who edited the ea
# ...

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
word_tokenize(df1["Review"][0])
# Out:
# ['pretty',
#  'lousy',
#  'madefortv',
#  'sequel',
#  'to',
#  'the',
#  'roman',
#  'polanski',
#  'classic',
#  'rosemarys',
#  'son',
#  'adrian',
#  'has',
#  'grown',
#  'up',
#  'and',
#  'is',
#  'embodied',
#  'by',
#  'creepy',
#  'stephen',
#  'mchattie',
#  'after',
#  'eliminating',
#  'rosemary',
#  'here',
#  'played',
#  'by',
#  'patty',
#  'duke',
#  'a',
#  'coven',
#  'of',
#  'witches',
#  'again',
#  'led',
#  'by',
#  'minnie',
#  'roman',
#  'castevets',
#  'preps',
#  'satans',
#  'son',
#  'for',
#  'world',
#  'domination',
#  'its',
#  'not',
#  'really',
#  'scary',
#  'and',
#  'light',
#  'years',
#  'less',
#  'macabre',
#  'than',
#  'its',
#  'predecessor',
#  'instead',
#  'writer',
#  'anthony',
#  'wilson',
#  'and',
#  'director',
#  'sam',
#  'osteen',
#  'opt',
#  'for',
#  'a',
#  'satanworshiping',
#  'thriller',
#  'full',
#  'of',
#  'a',
#  'lot',
#  'of',
#  'chanting',
#  'plenty',
#  'of',
#  'candles',
#  'and',
#  'ruth',
# ...

# %%
df1["Review"].map(lambda x : word_tokenize(x) )
# Out:
# 0       [pretty, lousy, madefortv, sequel, to, the, ro...
# 1       [a, fine, ironic, visual, gag, takes, place, i...
# 2       [this, is, the, worst, movie, i, have, seen, s...
# 3       [i, went, into, this, movie, perhaps, a, bit, ...
# 4       [captain, corellis, mandolin, is, a, fantastic...
#                               ...
# 9995    [very, businesslike, authority, with, little, ...
# 9996    [its, nice, that, these, three, young, directo...
# 9997    [i, rented, this, movie, tonight, because, it,...
# 9998    [in, all, truth, this, really, isnt, a, movie,...
# 9999    [anthony, quinn, is, a, master, at, capturing,...
# Name: Review, Length: 10000, dtype: object

# %%
df1
# Out:
#      sentiment                                             Review
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
# [10000 rows x 2 columns]

# %%
df1["Tokens"] = df1["Review"].map(lambda x : word_tokenize(x) )

# %%
df1
# Out:
#      sentiment                                             Review  \
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
#                                                  Tokens
# 0     [pretty, lousy, madefortv, sequel, to, the, ro...
# 1     [a, fine, ironic, visual, gag, takes, place, i...
# ...

# %% [markdown]
# ## **Stopwords**

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
sw_eng = stopwords.words("english")

# %%
df1.head()
# Out:
#   sentiment                                             Review  \
# 0  negative  pretty lousy madefortv sequel to the roman pol...
# 1  positive  a fine ironic visual gag takes place in front ...
# 2  negative  this is the worst movie i have seen since i kn...
# 3  positive  i went into this movie perhaps a bit jaded by ...
# 4  positive  captain corellis mandolin is a fantastic film ...
#
#                                               Tokens
# 0  [pretty, lousy, madefortv, sequel, to, the, ro...
# 1  [a, fine, ironic, visual, gag, takes, place, i...
# 2  [this, is, the, worst, movie, i, have, seen, s...
# 3  [i, went, into, this, movie, perhaps, a, bit, ...
# 4  [captain, corellis, mandolin, is, a, fantastic...

# %%
df1["Tokens"][0]
# Out:
# ['pretty',
#  'lousy',
#  'madefortv',
#  'sequel',
#  'to',
#  'the',
#  'roman',
#  'polanski',
#  'classic',
#  'rosemarys',
#  'son',
#  'adrian',
#  'has',
#  'grown',
#  'up',
#  'and',
#  'is',
#  'embodied',
#  'by',
#  'creepy',
#  'stephen',
#  'mchattie',
#  'after',
#  'eliminating',
#  'rosemary',
#  'here',
#  'played',
#  'by',
#  'patty',
#  'duke',
#  'a',
#  'coven',
#  'of',
#  'witches',
#  'again',
#  'led',
#  'by',
#  'minnie',
#  'roman',
#  'castevets',
#  'preps',
#  'satans',
#  'son',
#  'for',
#  'world',
#  'domination',
#  'its',
#  'not',
#  'really',
#  'scary',
#  'and',
#  'light',
#  'years',
#  'less',
#  'macabre',
#  'than',
#  'its',
#  'predecessor',
#  'instead',
#  'writer',
#  'anthony',
#  'wilson',
#  'and',
#  'director',
#  'sam',
#  'osteen',
#  'opt',
#  'for',
#  'a',
#  'satanworshiping',
#  'thriller',
#  'full',
#  'of',
#  'a',
#  'lot',
#  'of',
#  'chanting',
#  'plenty',
#  'of',
#  'candles',
#  'and',
#  'ruth',
# ...

# %%
len(df1["Tokens"][0])
# Out:
# 174

# %%
[ w  for w in df1["Tokens"][0] if w not in sw_eng]
# Out:
# ['pretty',
#  'lousy',
#  'madefortv',
#  'sequel',
#  'roman',
#  'polanski',
#  'classic',
#  'rosemarys',
#  'son',
#  'adrian',
#  'grown',
#  'embodied',
#  'creepy',
#  'stephen',
#  'mchattie',
#  'eliminating',
#  'rosemary',
#  'played',
#  'patty',
#  'duke',
#  'coven',
#  'witches',
#  'led',
#  'minnie',
#  'roman',
#  'castevets',
#  'preps',
#  'satans',
#  'son',
#  'world',
#  'domination',
#  'really',
#  'scary',
#  'light',
#  'years',
#  'less',
#  'macabre',
#  'predecessor',
#  'instead',
#  'writer',
#  'anthony',
#  'wilson',
#  'director',
#  'sam',
#  'osteen',
#  'opt',
#  'satanworshiping',
#  'thriller',
#  'full',
#  'lot',
#  'chanting',
#  'plenty',
#  'candles',
#  'ruth',
#  'gordon',
#  'trying',
#  'act',
#  'daffy',
#  'nasty',
#  'time',
#  'gordons',
#  'sole',
#  'holdover',
#  'original',
#  'george',
#  'maharis',
#  'replaces',
#  'john',
#  'cassavetes',
#  'guy',
#  'hammy',
#  'ray',
#  'milland',
#  'plays',
#  'roman',
#  'castevets',
# ...

# %%
len([ w  for w in df1["Tokens"][0] if w not in sw_eng])
# Out:
# 113

# %%
df1["Tokens"].map( lambda x : [w    for w in x  if w not in sw_eng])
# Out:
# 0       [pretty, lousy, madefortv, sequel, roman, pola...
# 1       [fine, ironic, visual, gag, takes, place, fron...
# 2       [worst, movie, seen, since, know, killed, lind...
# 3       [went, movie, perhaps, bit, jaded, hackandslas...
# 4       [captain, corellis, mandolin, fantastic, film,...
#                               ...
# 9995    [businesslike, authority, little, responsibili...
# 9996    [nice, three, young, directors, produced, film...
# 9997    [rented, movie, tonight, looked, like, fun, mo...
# 9998    [truth, really, isnt, movie, much, extended, f...
# 9999    [anthony, quinn, master, capturing, heart, sym...
# Name: Tokens, Length: 10000, dtype: object

# %%
df1["Tokens"] = df1["Tokens"].map( lambda x : [w    for w in x  if w not in sw_eng])

# %%
df1
# Out:
#      sentiment                                             Review  \
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
#                                                  Tokens
# 0     [pretty, lousy, madefortv, sequel, roman, pola...
# 1     [fine, ironic, visual, gag, takes, place, fron...
# ...

# %% [markdown]
# ## **Stemming**

# %%
from nltk.stem import PorterStemmer

# %%
port_stem = PorterStemmer()

# %%
df1
# Out:
#      sentiment                                             Review  \
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
#                                                  Tokens
# 0     [pretty, lousy, madefortv, sequel, roman, pola...
# 1     [fine, ironic, visual, gag, takes, place, fron...
# ...

# %%
df1["Tokens"].map(lambda x :  [port_stem.stem(w)  for w in x ])
# Out:
# 0       [pretti, lousi, madefortv, sequel, roman, pola...
# 1       [fine, iron, visual, gag, take, place, front, ...
# 2       [worst, movi, seen, sinc, know, kill, lindsey,...
# 3       [went, movi, perhap, bit, jade, hackandslash, ...
# 4       [captain, corelli, mandolin, fantast, film, no...
#                               ...
# 9995    [businesslik, author, littl, respons, desir, k...
# 9996    [nice, three, young, director, produc, film, g...
# 9997    [rent, movi, tonight, look, like, fun, movi, f...
# 9998    [truth, realli, isnt, movi, much, extend, fina...
# 9999    [anthoni, quinn, master, captur, heart, sympat...
# Name: Tokens, Length: 10000, dtype: object

# %%
df1["Tokens"] = df1["Tokens"].map(lambda x :  " ".join([port_stem.stem(w)  for w in x ]))

# %%
df1
# Out:
#      sentiment                                             Review  \
# 0     negative  pretty lousy madefortv sequel to the roman pol...
# 1     positive  a fine ironic visual gag takes place in front ...
# 2     negative  this is the worst movie i have seen since i kn...
# 3     positive  i went into this movie perhaps a bit jaded by ...
# 4     positive  captain corellis mandolin is a fantastic film ...
# ...        ...                                                ...
# 9995  negative  very businesslike authority with little respon...
# 9996  negative  its nice that these three young directors have...
# 9997  negative  i rented this movie tonight because it looked ...
# 9998  positive  in all truth this really isnt a movie so much ...
# 9999  positive  anthony quinn is a master at capturing our hea...
#
#                                                  Tokens
# 0     pretti lousi madefortv sequel roman polanski c...
# 1     fine iron visual gag take place front spectacu...
# ...
